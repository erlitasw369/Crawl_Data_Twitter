# %% [markdown]
# <a href="https://colab.research.google.com/github/erlitasw369/Crawl_Data_Twitter/blob/main/Crawl_Data_Twitter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Crawl Data Twitter

# %%
# Import required Python package
# !pip install pandas

# Install Node.js (because tweet-harvest built using Node.js)
# !sudo apt-get update
# !sudo apt-get install -y ca-certificates curl gnupg
# !sudo mkdir -p /etc/apt/keyrings
# !curl -fsSL https://deb.nodesource.com/gpgkey/nodesource-repo.gpg.key | sudo gpg --dearmor -o /etc/apt/keyrings/nodesource.gpg

# !NODE_MAJOR=20 && echo "deb [signed-by=/etc/apt/keyrings/nodesource.gpg] https://deb.nodesource.com/node_$NODE_MAJOR.x nodistro main" | sudo tee /etc/apt/sources.list.d/nodesource.list

# !sudo apt-get update
# !sudo apt-get install nodejs -y

# !node -v
# Out:
# ...
# Hit:1 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:2 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:3 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:4 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:5 https://ppa.launchpadcontent.net/c2d4u.team/c2d4u4.0+/ubuntu jammy InRelease
# Hit:6 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:7 https://deb.nodesource.com/node_20.x nodistro InRelease
# Hit:8 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:9 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:11 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Reading package lists... Done
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# ...

# %%
# Crawl Data

filename = 'palestine.csv'
search_keyword = 'palestine lang:id until:2023-10-15 since:2023-10-10'
limit = 1000

# !npx --yes tweet-harvest@latest -o "{filename}" -s "{search_keyword}" -l {limit} --token ""
# Out:
# Welcome to the Twitter Crawler 🕷️
#
# This script uses Chromium Browser to crawl data from Twitter with *your* Twitter auth token.
# Please enter your Twitter auth token when prompted.
#
# Note: Keep your access token secret! Don't share it with anyone else.
# Note: This script only runs on your local device.
#
# ...

# %%
import pandas as pd

# Specify the path to your CSV file
file_path = f"tweets_data/{filename}"

# Read the CSV file into a pandas DataFrame
df = pd.read_csv(file_path, delimiter=";")

# Display the DataFrame
display(df)
# Out:
#                          created_at               id_str  \
# 0    Sat Oct 14 23:59:35 +0000 2023  1713343827023692062
# 1    Sat Oct 14 23:58:28 +0000 2023  1713343545749455108
# 2    Sat Oct 14 23:58:26 +0000 2023  1713343539512533043
# 3    Sat Oct 14 23:58:01 +0000 2023  1713343434541482345
# 4    Sat Oct 14 23:58:00 +0000 2023  1713343427197456600
# ..                              ...                  ...
# 733  Sat Oct 14 17:27:23 +0000 2023  1713245126632571305
# 734  Sat Oct 14 17:26:49 +0000 2023  1713244982919016709
# 735  Sat Oct 14 17:26:40 +0000 2023  1713244947854643492
# 736  Sat Oct 14 17:26:23 +0000 2023  1713244875351846942
# 737  Sat Oct 14 17:26:06 +0000 2023  1713244803557999011
#
#                                              full_text  quote_count  \
# 0    Wahai umat Islam seluruh dunia bantu saudara m...            0
# 1    @TxtdariHI Cuma org waras yg bela palestine, s...            0
# 2    Kanak-kanak di Palestine menulis nama sendiri ...            0
# ...

# %%
# Cek jumlah data yang didapatkan

num_tweets = len(df)
print(f"Jumlah tweet dalam dataframe adalah {num_tweets}.")
# Out:
# Jumlah tweet dalam dataframe adalah 738.

# %% [markdown]
# # EDA, Preprocessing

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from tensorflow import keras
from tensorflow.keras import layers
from sklearn.preprocessing import LabelEncoder, StandardScaler

# %%
file_path = f"tweets_data/{filename}"
df = pd.read_csv(file_path, delimiter=";")
df.head()
# Out:
#                        created_at               id_str  \
# 0  Sat Oct 14 23:59:35 +0000 2023  1713343827023692062
# 1  Sat Oct 14 23:58:28 +0000 2023  1713343545749455108
# 2  Sat Oct 14 23:58:26 +0000 2023  1713343539512533043
# 3  Sat Oct 14 23:58:01 +0000 2023  1713343434541482345
# 4  Sat Oct 14 23:58:00 +0000 2023  1713343427197456600
#
#                                            full_text  quote_count  \
# 0  Wahai umat Islam seluruh dunia bantu saudara m...            0
# 1  @TxtdariHI Cuma org waras yg bela palestine, s...            0
# 2  Kanak-kanak di Palestine menulis nama sendiri ...            0
# 3                     @amber_rj Lanati insaan harami            0
# 4  mmg laa 100% disumbangkan ke tabung palestine....            0
#
#    reply_count  retweet_count  favorite_count lang          user_id_str  \
# 0            0              0               0   in  1603710343821201408
# 1            0              0               0   in  1423838140746190850
# ...

# %%
df.tail()
# Out:
#                          created_at               id_str  \
# 733  Sat Oct 14 17:27:23 +0000 2023  1713245126632571305
# 734  Sat Oct 14 17:26:49 +0000 2023  1713244982919016709
# 735  Sat Oct 14 17:26:40 +0000 2023  1713244947854643492
# 736  Sat Oct 14 17:26:23 +0000 2023  1713244875351846942
# 737  Sat Oct 14 17:26:06 +0000 2023  1713244803557999011
#
#                                              full_text  quote_count  \
# 733  @MirMAKOfficial In jahilo ko inky haal pay Chu...            0
# 734  Ini contoh ringkas  apa yg kelab EPL support d...            0
# 735  Orang2 arab penakut itu cukup duduk diam saja ...            0
# 736  @naimdanielx Mahal sial. Bendera Palestine tu ...            0
# 737  suruh orang evacuate sekali bom, bodoh puak ni...            0
#
#      reply_count  retweet_count  favorite_count lang          user_id_str  \
# 733            0              0               0   in  1445039984751357957
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 738 entries, 0 to 737
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   created_at           738 non-null    object
#  1   id_str               738 non-null    int64
#  2   full_text            738 non-null    object
#  3   quote_count          738 non-null    int64
#  4   reply_count          738 non-null    int64
#  5   retweet_count        738 non-null    int64
#  6   favorite_count       738 non-null    int64
#  7   lang                 738 non-null    object
#  8   user_id_str          738 non-null    int64
#  9   conversation_id_str  738 non-null    int64
#  10  username             738 non-null    object
#  11  tweet_url            738 non-null    object
# dtypes: int64(7), object(5)
# memory usage: 69.3+ KB

# %%
df.describe()
# Out:
#              id_str  quote_count  reply_count  retweet_count  favorite_count  \
# count  7.380000e+02   738.000000   738.000000     738.000000      738.000000
# mean   1.713287e+18     0.074526     0.409214       1.815718        7.719512
# std    3.165583e+13     0.564558     2.142298      19.983336       72.014820
# min    1.713245e+18     0.000000     0.000000       0.000000        0.000000
# 25%    1.713258e+18     0.000000     0.000000       0.000000        0.000000
# 50%    1.713279e+18     0.000000     0.000000       0.000000        0.000000
# 75%    1.713318e+18     0.000000     0.000000       0.000000        1.000000
# max    1.713344e+18    10.000000    46.000000     511.000000     1775.000000
#
#         user_id_str  conversation_id_str
# count  7.380000e+02         7.380000e+02
# mean   9.169893e+17         1.711043e+18
# std    6.652230e+17         4.015942e+16
# min    1.572558e+07         9.420287e+17
# 25%    2.762329e+09         1.713216e+18
# ...

# %%
df.isna().sum()
# Out:
# created_at             0
# id_str                 0
# full_text              0
# quote_count            0
# reply_count            0
# retweet_count          0
# favorite_count         0
# lang                   0
# user_id_str            0
# conversation_id_str    0
# username               0
# tweet_url              0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.columns
print(df.shape)
# Out:
# (738, 12)

# %%
le = LabelEncoder()
for column in df.columns:
    if df[column].dtype == 'object':
        df[column] = le.fit_transform(df[column])
df.dtypes
# Out:
# created_at             int64
# id_str                 int64
# full_text              int64
# quote_count            int64
# reply_count            int64
# retweet_count          int64
# favorite_count         int64
# lang                   int64
# user_id_str            int64
# conversation_id_str    int64
# username               int64
# tweet_url              int64
# dtype: object
